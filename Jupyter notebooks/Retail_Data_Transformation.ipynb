# %%
import pandas as pd
import numpy as np

# %%
cust = pd.read_csv("Customers.csv", encoding="latin1",sep=";")
cust.head(10)
# Out:
#   Customer ID         Customer Name
# 0    AA-10315            Alex Avila
# 1    AA-10375          Allen Armold
# 2    AA-10480          Andrew Allen
# 3    AA-10645         Anna Andreadi
# 4    AB-10015         Aaron Bergman
# 5    AB-10060       Adam Bellavance
# 6    AB-10105         Adrian Barton
# 7    AB-10150           Aimee Bixby
# 8    AB-10165           Alan Barnes
# 9    AB-10255  Alejandro Ballentine

# %%
cust.shape
# Out:
# (793, 2)

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    793 non-null    object
#  1   Customer Name  793 non-null    object
# dtypes: object(2)
# memory usage: 12.5+ KB

# %%
cust.isnull().sum()
# Out:
# Customer ID      0
# Customer Name    0
# dtype: int64

# %%
cust.duplicated().sum()
# Out:
# np.int64(0)

# %%
cust.nunique()
# Out:
# Customer ID      793
# Customer Name    793
# dtype: int64

# %%
cust.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Customers_Transformed.xlsx",
    index=False
)

# %% [markdown]
# ------------------------------------------------------

# %%
loct = pd.read_csv("Location.csv", encoding="latin1",sep=";")
loct.head(10)
# Out:
#    Postal Code        City      State   Region Country/Region
# 0      76106.0  Fort Worth      Texas  Central  United States
# 1      53711.0     Madison  Wisconsin  Central  United States
# 2      68025.0     Fremont   Nebraska  Central  United States
# 3      77095.0     Houston      Texas  Central  United States
# 4      75080.0  Richardson      Texas  Central  United States
# 5      77041.0     Houston      Texas  Central  United States
# 6      60540.0  Naperville   Illinois  Central  United States
# 7      55122.0       Eagan  Minnesota  Central  United States
# 8      48185.0    Westland   Michigan  Central  United States
# 9      47150.0  New Albany    Indiana  Central  United States

# %%
loct.shape
# Out:
# (632, 5)

# %%
loct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Postal Code     631 non-null    float64
#  1   City            632 non-null    object
#  2   State           632 non-null    object
#  3   Region          632 non-null    object
#  4   Country/Region  632 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 24.8+ KB

# %%
loct.isnull().sum()
# Out:
# Postal Code       1
# City              0
# State             0
# Region            0
# Country/Region    0
# dtype: int64

# %%
loct.duplicated().sum()
# Out:
# np.int64(0)

# %%
loct.nunique()
# Out:
# Postal Code       630
# City              531
# State              49
# Region              4
# Country/Region      1
# dtype: int64

# %%
loct[loct["State"] == "Texas"].head(10)
# Out:
#     Postal Code           City  State   Region Country/Region
# 0       76106.0     Fort Worth  Texas  Central  United States
# 3       77095.0        Houston  Texas  Central  United States
# 4       75080.0     Richardson  Texas  Central  United States
# 5       77041.0        Houston  Texas  Central  United States
# 12      77070.0        Houston  Texas  Central  United States
# 23      78207.0    San Antonio  Texas  Central  United States
# 24      77036.0        Houston  Texas  Central  United States
# 26      75051.0  Grand Prairie  Texas  Central  United States
# 27      75220.0         Dallas  Texas  Central  United States
# 31      77506.0       Pasadena  Texas  Central  United States

# %%
loct.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Location_Transformed.xlsx",
    index=False
)

# %%
loct = loct.drop_duplicates(subset=["Postal Code"])

# %%
loct
# Out:
#      Postal Code             City       State   Region Country/Region
# 0        76106.0       Fort Worth       Texas  Central  United States
# 1        53711.0          Madison   Wisconsin  Central  United States
# 2        68025.0          Fremont    Nebraska  Central  United States
# 3        77095.0          Houston       Texas  Central  United States
# 4        75080.0       Richardson       Texas  Central  United States
# ..           ...              ...         ...      ...            ...
# 627      83301.0       Twin Falls       Idaho     West  United States
# 628      92672.0     San Clemente  California     West  United States
# 629      94568.0           Dublin  California     West  United States
# 630      93405.0  San Luis Obispo  California     West  United States
# 631      95240.0             Lodi  California     West  United States
#
# [631 rows x 5 columns]

# %%
loct.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Location_Transformed_again.xlsx",
    index=False
)

# %%
print("Total Rows:", len(loct))
# Out:
# Total Rows: 631

# %%
print("Unique Postal Codes:", loct["Postal Code"].nunique())
# Out:
# Unique Postal Codes: 630

# %%
print("Duplicate Postal Codes:", loct["Postal Code"].duplicated().sum())
# Out:
# Duplicate Postal Codes: 0

# %%
loct_dim = loct.drop_duplicates(subset=["Postal Code"])

print(loct_dim.shape)
# Out:
# (631, 5)

# %%
loct.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Location_Transformed_again_again.xlsx",
    index=False
)

# %%
loct = loct.dropna(subset=["Postal Code"])

# %%
loct.isnull().sum()
# Out:
# Postal Code       0
# City              0
# State             0
# Region            0
# Country/Region    0
# dtype: int64

# %%
loct.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Location_Transformed_again_a.xlsx",
    index=False
)

# %% [markdown]
# -------------------------------------------------------

# %%
orders = pd.read_csv(
    "Orders.csv",encoding="latin1",
    sep=";",
    decimal=","
)
orders
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2022-152156  08/11/2022  11/11/2022    Second Class
# 1          2  CA-2022-152156  08/11/2022  11/11/2022    Second Class
# 2          3  CA-2022-138688  12/06/2022  16/06/2022    Second Class
# 3          4  US-2021-108966  11/10/2021  18/10/2021  Standard Class
# 4          5  US-2021-108966  11/10/2021  18/10/2021  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2020-110422  21/01/2020  23/01/2020    Second Class
# 9990    9991  CA-2023-121258  26/02/2023  03/03/2023  Standard Class
# 9991    9992  CA-2023-121258  26/02/2023  03/03/2023  Standard Class
# 9992    9993  CA-2023-121258  26/02/2023  03/03/2023  Standard Class
# 9993    9994  CA-2023-119914  04/05/2023  09/05/2023    Second Class
#
#      Customer ID    Segment  Postal Code       Product ID     Sales  Quantity  \
# ...

# %%
orders.shape
# Out:
# (9994, 13)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Row ID       9994 non-null   int64
#  1   Order ID     9994 non-null   object
#  2   Order Date   9994 non-null   object
#  3   Ship Date    9994 non-null   object
#  4   Ship Mode    9994 non-null   object
#  5   Customer ID  9994 non-null   object
#  6   Segment      9994 non-null   object
#  7   Postal Code  9994 non-null   int64
#  8   Product ID   9994 non-null   object
#  9   Sales        9994 non-null   float64
#  10  Quantity     9994 non-null   int64
#  11  Discount     9994 non-null   float64
#  12  Profit       9994 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1015.1+ KB

# %%
orders.isnull().sum()
# Out:
# Row ID         0
# Order ID       0
# Order Date     0
# Ship Date      0
# Ship Mode      0
# Customer ID    0
# Segment        0
# Postal Code    0
# Product ID     0
# Sales          0
# Quantity       0
# Discount       0
# Profit         0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.nunique()
# Out:
# Row ID         9994
# Order ID       5009
# Order Date     1236
# Ship Date      1334
# Ship Mode         4
# Customer ID     793
# Segment           3
# Postal Code     630
# Product ID     1862
# Sales          5825
# Quantity         14
# Discount         12
# Profit         7287
# dtype: int64

# %%
orders[(orders["Ship Mode"] == "Second Class") & (orders["Segment"] == "Consumer")].head(10)
# Out:
#     Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0        1  CA-2022-152156  08/11/2022  11/11/2022  Second Class    CG-12520
# 1        2  CA-2022-152156  08/11/2022  11/11/2022  Second Class    CG-12520
# 17      18  CA-2020-167164  13/05/2020  15/05/2020  Second Class    AG-10270
# 18      19  CA-2020-143336  27/08/2020  01/09/2020  Second Class    ZD-21925
# 19      20  CA-2020-143336  27/08/2020  01/09/2020  Second Class    ZD-21925
# 20      21  CA-2020-143336  27/08/2020  01/09/2020  Second Class    ZD-21925
# 23      24  US-2023-156909  16/07/2023  18/07/2023  Second Class    SF-20065
# 25      26  CA-2022-121755  16/01/2022  20/01/2022  Second Class    EH-13945
# 26      27  CA-2022-121755  16/01/2022  20/01/2022  Second Class    EH-13945
# 46      47  CA-2020-146703  20/10/2020  25/10/2020  Second Class    PO-18865
#
#      Segment  Postal Code       Product ID    Sales  Quantity  Discount  \
# ...

# %%
orders["Order Date"] = pd.to_datetime(
    orders["Order Date"],
    format="%d/%m/%Y"
)
orders["Ship Date"] = pd.to_datetime(
    orders["Ship Date"],
    format="%d/%m/%Y"
)

# %%
orders.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Orders_Transformed.xlsx",
    index=False
)

# %%
print("Total Rows:", len(orders))
# Out:
# Total Rows: 9994

# %%
print("Unique Postal Codes:", orders["Postal Code"].nunique())
# Out:
# Unique Postal Codes: 630

# %% [markdown]
# -------------------------------------------

# %%
prod = pd.read_csv("Products.csv", encoding="latin1",sep=";")
prod.head(10)
# Out:
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10000112  Furniture    Bookcases
# 1  FUR-BO-10000330  Furniture    Bookcases
# 2  FUR-BO-10000362  Furniture    Bookcases
# 3  FUR-BO-10000468  Furniture    Bookcases
# 4  FUR-BO-10000711  Furniture    Bookcases
# 5  FUR-BO-10000780  Furniture    Bookcases
# 6  FUR-BO-10001337  Furniture    Bookcases
# 7  FUR-BO-10001519  Furniture    Bookcases
# 8  FUR-BO-10001567  Furniture    Bookcases
# 9  FUR-BO-10001601  Furniture    Bookcases
#
#                                         Product Name
# 0   Bush Birmingham Collection Bookcase, Dark Cherry
# 1  Sauder Camden County Barrister Bookcase, Plank...
# 2                 Sauder Inglewood Library Bookcases
# 3            O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4                          Hon Metal Bookcases, Gray
# 5  O'Sullivan Plantations 2-Door Library in Landv...
# 6     O'Sullivan Living Dimensions 2-Shelf Bookcases
# 7            O'Sullivan 3-Shelf Heavy-Duty Bookcases
# ...

# %%
prod.shape
# Out:
# (1894, 4)

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product ID    1894 non-null   object
#  1   Category      1894 non-null   object
#  2   Sub-Category  1894 non-null   object
#  3   Product Name  1894 non-null   object
# dtypes: object(4)
# memory usage: 59.3+ KB

# %%
prod.isnull().sum()
# Out:
# Product ID      0
# Category        0
# Sub-Category    0
# Product Name    0
# dtype: int64

# %%
prod.duplicated().sum()
# Out:
# np.int64(0)

# %%
prod.nunique()
# Out:
# Product ID      1862
# Category           3
# Sub-Category      17
# Product Name    1849
# dtype: int64

# %%
prod[(prod["Category"]=="Furniture") & (prod["Sub-Category"]=="Bookcases")].head(10)
# Out:
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10000112  Furniture    Bookcases
# 1  FUR-BO-10000330  Furniture    Bookcases
# 2  FUR-BO-10000362  Furniture    Bookcases
# 3  FUR-BO-10000468  Furniture    Bookcases
# 4  FUR-BO-10000711  Furniture    Bookcases
# 5  FUR-BO-10000780  Furniture    Bookcases
# 6  FUR-BO-10001337  Furniture    Bookcases
# 7  FUR-BO-10001519  Furniture    Bookcases
# 8  FUR-BO-10001567  Furniture    Bookcases
# 9  FUR-BO-10001601  Furniture    Bookcases
#
#                                         Product Name
# 0   Bush Birmingham Collection Bookcase, Dark Cherry
# 1  Sauder Camden County Barrister Bookcase, Plank...
# 2                 Sauder Inglewood Library Bookcases
# 3            O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4                          Hon Metal Bookcases, Gray
# 5  O'Sullivan Plantations 2-Door Library in Landv...
# 6     O'Sullivan Living Dimensions 2-Shelf Bookcases
# 7            O'Sullivan 3-Shelf Heavy-Duty Bookcases
# ...

# %%
prod.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Products_Transformed.xlsx",
    index=False
)

# %%
prod["Product ID"].duplicated().sum()
# Out:
# np.int64(32)

# %%
prod["Product ID"].nunique()
# Out:
# 1862

# %%
len(prod)
# Out:
# 1894

# %%
prod = prod.drop_duplicates(subset=["Product ID"])

# %%
prod
# Out:
#            Product ID    Category Sub-Category  \
# 0     FUR-BO-10000112   Furniture    Bookcases
# 1     FUR-BO-10000330   Furniture    Bookcases
# 2     FUR-BO-10000362   Furniture    Bookcases
# 3     FUR-BO-10000468   Furniture    Bookcases
# 4     FUR-BO-10000711   Furniture    Bookcases
# ...               ...         ...          ...
# 1889  TEC-PH-10004912  Technology       Phones
# 1890  TEC-PH-10004922  Technology       Phones
# 1891  TEC-PH-10004924  Technology       Phones
# 1892  TEC-PH-10004959  Technology       Phones
# 1893  TEC-PH-10004977  Technology       Phones
#
#                                            Product Name
# 0      Bush Birmingham Collection Bookcase, Dark Cherry
# 1     Sauder Camden County Barrister Bookcase, Plank...
# 2                    Sauder Inglewood Library Bookcases
# 3               O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4                             Hon Metal Bookcases, Gray
# ...                                                 ...
# ...

# %%
prod.to_excel(
    r"C:\Users\AmanGogna\OneDrive - techcarrot.ae\Desktop\Products_Transformed_again.xlsx",
    index=False
)
